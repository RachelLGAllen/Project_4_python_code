# %% [markdown]
# ## 4.7 Deriving New Variables

# %% [markdown]
# ### This script contains the following points:
#
# #### 1. Create data to experiment on
# #### 2. Create new row to label price data
# #### 3. Create new row for business of days of week
# #### 4. Check data and export

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/rachelallen/CareerFoundry Achievement 4/08-2022 Instacart Basket Analysis/02 Data'

# %%
# import the ords_prods_merged dataframe
ords_prods_merged2 = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged2.pkl'))

# %%
df = ords_prods_merged2[:1000000]

# %%
#create new row to label price data
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#apply the function on 'price_range'
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/sg/643_lsvj2pj89g1m5qn18t800000gp/T/ipykernel_5137/1557023608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
df.head()
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour  \
# 0  2539329.0      1.0           1.0                2.0         8.0
# 1  2398795.0      1.0           2.0                3.0         7.0
# 2   473747.0      1.0           3.0                3.0        12.0
# 3  2254736.0      1.0           4.0                4.0         7.0
# 4   431534.0      1.0           5.0                4.0        15.0
#
#    days_since_prior_order            flagged  product_id  add_to_cart_order  \
# 0                     NaN  No Previous Order         196                1.0
# 1                    15.0     Previous Order         196                1.0
# 2                    21.0     Previous Order         196                1.0
# 3                    29.0     Previous Order         196                1.0
# 4                    28.0     Previous Order         196                1.0
#
#    reordered _merge product_name  aisle_id  department_id  prices Exists  \
# ...

# %%
# use .loc() to create price_range_loc on whole df
ords_prods_merged2.loc[ords_prods_merged2['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged2.loc[(ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged2.loc[ords_prods_merged2['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged2['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                   21891068
# Low-range product     10126324
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
#for loops
for x in range (5, 10):
    print ("My age is %d" %(x))
# Out:
# My age is 5
# My age is 6
# My age is 7
# My age is 8
# My age is 9

# %%
#check for busy days 
ords_prods_merged2['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0.0    6209808
# 1.0    5665951
# 6.0    4500391
# 2.0    4217868
# 5.0    4209603
# 3.0    3844175
# 4.0    3787263
# NaN         11
# Name: order_day_of_week, dtype: int64

# %%
result = []

for value in ords_prods_merged2["order_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#create a new column for this info
ords_prods_merged2['busiest_day'] = result

# %%
ords_prods_merged2['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437999
# Busiest day        6209808
# Least busy         3787263
# Name: busiest_day, dtype: int64

# %%
# 2: create new column "busiest_days" w/ 2 busiest and least busy days
ords_prods_merged2['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0.0    6209808
# 1.0    5665951
# 6.0    4500391
# 2.0    4217868
# 5.0    4209603
# 3.0    3844175
# 4.0    3787263
# NaN         11
# Name: order_day_of_week, dtype: int64

# %%
result = []

for value in ords_prods_merged2["order_day_of_week"]:
  if value == 0 or value == 1:
    result.append("Busiest days")
  elif value == 4 or value == 3:
    result.append("Least busy days")
  else:
    result.append("Regularly busy")

# %%
#create a new column for this info
ords_prods_merged2['busiest_days'] = result

# %%
ords_prods_merged2['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy     12927873
# Busiest days       11875759
# Least busy days     7631438
# Name: busiest_days, dtype: int64

# %%
ords_prods_merged2.head()
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour  \
# 0  2539329.0      1.0           1.0                2.0         8.0
# 1  2398795.0      1.0           2.0                3.0         7.0
# 2   473747.0      1.0           3.0                3.0        12.0
# 3  2254736.0      1.0           4.0                4.0         7.0
# 4   431534.0      1.0           5.0                4.0        15.0
#
#    days_since_prior_order            flagged  product_id  add_to_cart_order  \
# 0                     NaN  No Previous Order         196                1.0
# 1                    15.0     Previous Order         196                1.0
# 2                    21.0     Previous Order         196                1.0
# 3                    29.0     Previous Order         196                1.0
# 4                    28.0     Previous Order         196                1.0
#
#    reordered _merge product_name  aisle_id  department_id  prices Exists  \
# ...

# %% [markdown]
# #### check the values
# Looks right: the values are about doubled

# %%
# Create a new column containing these labels called “busiest_period_of_day.
ords_prods_merged2['order_hour'].value_counts()
# Out:
# 10.0    2764476
# 11.0    2738647
# 14.0    2691598
# 15.0    2664583
# 13.0    2663346
# 12.0    2620898
# 16.0    2537506
# 9.0     2456751
# 17.0    2089510
# 8.0     1719991
# 18.0    1637956
# 19.0    1259416
# 20.0     977049
# 7.0      891951
# 21.0     796379
# 22.0     634743
# 23.0     402621
# 6.0      290796
# 0.0      218951
# 1.0      115787
# 5.0       88064
# 2.0       69435
# 4.0       53284
# 3.0       51321
# Name: order_hour, dtype: int64

# %%
#  they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.”
result = []

for value in ords_prods_merged2['order_hour']:
  if value == 10 or value == 11:
    result.append("Most orders")
  elif value == 2 or value == 3 or value == 4:
    result.append("Fewest orders")
  else:
    result.append("Average orders")

# %%
ords_prods_merged2['busiest_period_of_day'] = result

# %% [raw]
# # 5 check the frequency of these columns

# %%
ords_prods_merged2['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Average orders    26757907
# Most orders        5503123
# Fewest orders       174040
# Name: busiest_period_of_day, dtype: int64

# %%
# 7 export as pickle in Prepared Data folder
ords_prods_merged2.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %%
ords_prods_merged2.head()
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour  \
# 0  2539329.0      1.0           1.0                2.0         8.0
# 1  2398795.0      1.0           2.0                3.0         7.0
# 2   473747.0      1.0           3.0                3.0        12.0
# 3  2254736.0      1.0           4.0                4.0         7.0
# 4   431534.0      1.0           5.0                4.0        15.0
#
#    days_since_prior_order            flagged  product_id  add_to_cart_order  \
# 0                     NaN  No Previous Order         196                1.0
# 1                    15.0     Previous Order         196                1.0
# 2                    21.0     Previous Order         196                1.0
# 3                    29.0     Previous Order         196                1.0
# 4                    28.0     Previous Order         196                1.0
#
#    reordered _merge product_name  aisle_id  department_id  prices Exists  \
# ...
